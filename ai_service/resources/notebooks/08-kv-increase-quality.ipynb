# %%
# %pip install torchsr
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from torchsr.datasets import Div2K
from torchsr.models import ninasr_b2
from torchsr.models import edsr, rcan
from torchvision.transforms.functional import to_pil_image, to_tensor
from torchsr.models.utils import ChoppedModel, SelfEnsembleModel

from PIL import Image

# Open an image file
image = Image.open("butterfly.png")

# Download a pretrained NinaSR model
model = ChoppedModel(
    rcan(scale=2, pretrained=True), scale=2,
    chop_size=400, chop_overlap=10)

# Run the Super-Resolution model
lr_t = to_tensor(image).unsqueeze(0)
sr_t = model(lr_t)
sr = to_pil_image(sr_t.squeeze(0))
sr.save("butterfly_better.png")

# %%
# %pip install opencv-contrib-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.7/68.7 MB 3.8 MB/s eta 0:00:0000:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2

sr = cv2.dnn_superres.DnnSuperResImpl_create()
sr.readModel("EDSR_x4.pb")
sr.setModel("edsr", 4)  # Or "edsr" for EDSR model
# Upscale the image
upscaled_image = sr.upsample(opencv_image)

# %%
cv2.imwrite("AAA.png", upscaled_image)
# Out:
# True

# %%
image3 = Image.open("../test_images/upscale_image/image1.jpg").convert('RGB')
# opencv_image = np.array(image3)
# opencv_image = cv2.cvtColor(opencv_image, cv2.COLOR_RGB2BGR)

# %%
from PIL import Image

# %%
request_dict ={}
request_dict["type"] = "transfer_style"
request_dict["params"] = {}
request_dict["params"]["image"] = Image.open("a.jpg")
request_dict["params"]["style"] = "vangogh"

# %%
result = invoker.process_request(request_dict)
# Out:
# vangogh

# %%
result
# Out:
# <PIL.Image.Image image mode=RGB size=688x512>

# %%
request_dict = {}
request_dict["type"] = "upscale"
request_dict["params"] = {}
request_dict["params"]["image"] = image3

# %%
result = invoker.process_request(request_dict)

# %%
# %pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
from torchvision import transforms
from PIL import Image


# Convert tensor to PIL image
to_pil = transforms.ToPILImage()
pil_image = to_pil(result[0])

# Display the image (optional)
pil_image
# Out:
# <PIL.Image.Image image mode=RGB size=600x600>

# %%
image3 = np.array(image3)
if len(image3.shape) == 3 and image3.shape[2] == 4:
    print("AAAA")
# Out:
# AAAA

# %%
# %pip install opencv-python
import cv2
img = cv2.imread("../test_images/upscale_image/image1.jpg", cv2.IMREAD_UNCHANGED)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
img.shape
# Out:
# (300, 300, 4)
